# %% [markdown]
# <h1 style='color: blue'>DATA ANALYTICS PROJECT</h1>
# <h2 style='color: maroon'>Dengue Cases💀</h2>
# <h2 style='color: gold'>Analyst: Brian Perez</h2>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import f_oneway

import warnings
warnings.filterwarnings('ignore')

dengue = pd.read_csv('dengue.csv')
dengue
# Out:
#           Month  Year    Region  Dengue_Cases  Dengue_Deaths
# 0       January  2016  Region I           705              1
# 1      February  2016  Region I           374              0
# 2         March  2016  Region I           276              0
# 3         April  2016  Region I           240              2
# 4           May  2016  Region I           243              1
# ...         ...   ...       ...           ...            ...
# 1015     August  2020     BARMM            91              0
# 1016  September  2020     BARMM            16              8
# 1017    October  2020     BARMM            13              9
# 1018   November  2020     BARMM            15              1
# 1019   December  2020     BARMM            23              0
#
# [1020 rows x 5 columns]

# %% [markdown]
# <h1 style='color: blue'>Insight 1</h1>
# <h3>The month of <span style='color: maroon; font-wieght: bold;'>August</span> recorded the highest average number of dengue cases in a year, indicating a peak in dengue incidence during this period.</h3>

# %%
monthly_avg_cases = dengue.groupby("Month")["Dengue_Cases"].mean()
month_order = [
    "January", "February", "March", "April", "May", "June", 
    "July", "August", "September", "October", "November", "December"
]
monthly_avg_cases = monthly_avg_cases.reindex(month_order)
highest_avg_month = monthly_avg_cases.idxmax()
highest_avg_cases = monthly_avg_cases.max()

print(f"The month with the highest average dengue cases is {highest_avg_month} with an average of {highest_avg_cases:.2f} cases.")

plt.figure(figsize=(10, 5))
sns.barplot(x=monthly_avg_cases.index, y=monthly_avg_cases.values, palette="coolwarm")
plt.xticks(rotation=45)
plt.xlabel("Month")
plt.ylabel("Average Dengue Cases")
plt.title("Average Dengue Cases per Month")
plt.axhline(highest_avg_cases, color="red", linestyle="--", label=f"Highest: {highest_avg_month}")
plt.legend()
plt.show()
# Out:
# The month with the highest average dengue cases is August with an average of 2206.52 cases.

# %% [markdown]
# <h1 style='color:blue'>Insight 2</h1>
# <h3>The National Capital Region (NCR) recorded the highest number of dengue-related deaths, with a total of <span style='color: maroon'>4008</span> deaths. This highlights a critical need for enhanced dengue prevention and control measures in the area. </h3>

# %%
region_death_cases = dengue.groupby("Region")["Dengue_Deaths"].sum()

highest_death_region = region_death_cases.idxmax()
highest_death_cases = region_death_cases.max()

print(f'The region with the highest death case is "{highest_death_region}" with "{highest_death_cases} deaths" in whole year')

plt.figure(figsize=(12, 6))
sns.barplot(x=region_death_cases.index, y=region_death_cases.values, palette="Reds_r")
plt.xticks(rotation=45)
plt.xlabel("Region")
plt.ylabel("Total Dengue Deaths")
plt.title("Total Dengue Deaths by Region")
plt.axhline(highest_death_cases, color="black", linestyle="--", label=f"Highest: {highest_death_region}")
plt.legend()
plt.show()
# Out:
# The region with the highest death case is "NCR" with "4008 deaths" in whole year

# %% [markdown]
# <h1 style='color:blue'>Insight 3</h1>
# <h3>The highest average number of dengue deaths occurs in <span style='color:maroon;'>October</span>, followed by September. This trend suggests a peak in dengue fatalities during these months, highlighting a potential seasonal pattern.</h3>

# %%
monthly_avg_deaths = dengue.groupby("Month")["Dengue_Deaths"].mean()
highest_avg_death_month = monthly_avg_deaths.idxmax()
highest_avg_deaths = monthly_avg_deaths.max()

print(f"The month with the highest average dengue deaths is {highest_avg_death_month} with {highest_avg_deaths:.2f} deaths.")

plt.figure(figsize=(10, 5))
sns.barplot(x=monthly_avg_deaths.index, y=monthly_avg_deaths.values, palette="magma")
plt.xticks(rotation=45)
plt.xlabel("Month")
plt.ylabel("Average Dengue Deaths")
plt.title("Average Dengue Deaths per Month")
plt.axhline(highest_avg_deaths, color="red", linestyle="--", label=f"Highest: {highest_avg_death_month}")
plt.legend()
plt.show()
# Out:
# The month with the highest average dengue deaths is October with 78.47 deaths.

# %% [markdown]
# <h1 style='color:blue'>Insight 4</h1>
# <h3>The highest number of dengue cases was recorded in <span style='color:maroon;'>2019</span>, marking a significant outbreak. This suggests that 2019 experienced the most severe dengue spread compared to other years.</h3>

# %%
yearly_cases = dengue.groupby("Year")["Dengue_Cases"].sum()
highest_case_year = yearly_cases.idxmax()
highest_case_value = yearly_cases.max()

print(f"The year with the highest total dengue cases is {highest_case_year} with {highest_case_value} cases.")

plt.figure(figsize=(10, 5))
sns.barplot(x=yearly_cases.index, y=yearly_cases.values, palette="Blues")
plt.xlabel("Year")
plt.ylabel("Total Dengue Cases")
plt.title("Total Dengue Cases per Year")
plt.axhline(highest_case_value, color="red", linestyle="--", label=f"Highest: {highest_case_year}")
plt.legend()
plt.show()
# Out:
# The year with the highest total dengue cases is 2019 with 441902 cases.

# %% [markdown]
# <h1 style='color:blue'>Insight 5</h1>
# <h3>The highest total number of dengue deaths was recorded in 2016, indicating a peak in fatalities that year. This suggests that 2016 experienced the deadliest dengue outbreak compared to other years.</h3>

# %%
yearly_deaths = dengue.groupby("Year")["Dengue_Deaths"].sum()
highest_death_year = yearly_deaths.idxmax()
highest_death_value = yearly_deaths.max()

print(f"The year with the highest total dengue deaths is {highest_death_year} with {highest_death_value} deaths.")

plt.figure(figsize=(10, 5))
sns.barplot(x=yearly_deaths.index, y=yearly_deaths.values, palette="Reds")
plt.xlabel("Year")
plt.ylabel("Total Dengue Deaths")
plt.title("Total Dengue Deaths per Year")
plt.axhline(highest_death_value, color="red", linestyle="--", label=f"Highest: {highest_death_year}")
plt.legend()
plt.show()
# Out:
# The year with the highest total dengue deaths is 2016 with 8127 deaths.

# %% [markdown]
# <h1 style='color:blue'>Insight 6</h1>
# <h3>August consistently records the highest number of dengue cases over time, indicating a seasonal surge in infections. This trend suggests that dengue transmission peaks during this month each year.</h3>

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=dengue, x="Month", y="Dengue_Cases", marker="o", label="Dengue Cases")
plt.xlabel("Months")
plt.ylabel("Dengue Cases")
plt.title("Dengue Cases Over Time")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# <h1 style='color:blue'>Insight 7</h1>
# <h3>Among the top five years with the most dengue cases, 2019 recorded the highest number. This highlights 2019 as the peak year for dengue outbreaks.</h3>

# %%
top_5_cases = yearly_cases.nlargest(5)

plt.figure(figsize=(8, 5))
sns.barplot(x=top_5_cases.index, y=top_5_cases.values, palette="coolwarm")
plt.xlabel("Year")
plt.ylabel("Dengue Cases")
plt.title("Top 5 Years with the Most Dengue Cases")
plt.show()

# %% [markdown]
# <h1 style='color:blue'>Insight 8</h1>
# <h3>Among the top five years with the most dengue deaths, 2016 recorded the highest fatalities. This indicates that 2016 experienced the deadliest dengue outbreak.</h3>

# %%
top_5_deaths = yearly_deaths.nlargest(5)

plt.figure(figsize=(8, 5))
sns.barplot(x=top_5_deaths.index, y=top_5_deaths.values, palette="magma")
plt.xlabel("Year")
plt.ylabel("Dengue Deaths")
plt.title("Top 5 Years with the Most Dengue Deaths")
plt.show()

# %% [markdown]
# <h1 style='color:blue'>Insight 9</h1>
# <h3>Dengue cases peak from June to October, with August showing the highest spikes, indicating increased transmission during the rainy season.</h3>

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(data=dengue, x="Month", y="Dengue_Cases", palette="coolwarm")
plt.xlabel("Day of the Month")
plt.ylabel("Dengue Cases")
plt.title("Daily Distribution of Dengue Cases")
plt.show()

# %% [markdown]
# <h1 style='color:blue'>Insight 10</h1>
# <h3>Dengue deaths vary each year, with some years having extreme spikes in fatalities. This suggests that certain years had severe outbreaks, possibly due to environmental or healthcare factors.</h3>

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x="Year", y="Dengue_Deaths", data=dengue, palette="magma")
plt.xlabel("Year")
plt.ylabel("Dengue Deaths")
plt.title("Dengue Deaths per Year - Box Plot")
plt.show()

# %% [markdown]
# <h1 style='color:blue'>Insight 11</h1>
# <h3>September has the highest number of dengue cases, with an average of 5,273.1 cases. August follows closely behind, showing a peak in dengue infections during these months.</h3>

# %%
pivot_cases = dengue.pivot_table(index="Year", columns="Month", values="Dengue_Cases", aggfunc="mean")
plt.figure(figsize=(12, 6))
sns.heatmap(pivot_cases.reindex(columns=month_order), cmap="coolwarm", annot=True, fmt=".1f")
plt.title("Heatmap of Monthly Dengue Cases")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <h1 style='color:blue'>Insight 12</h1>
# <h3>The histogram shows that most dengue cases are low in number, but there are some extreme cases reaching over 20,000. The data is highly skewed, indicating that while most cases remain moderate, severe outbreaks occasionally occur.</h3>

# %%
plt.figure(figsize=(10, 5))
sns.histplot(dengue["Dengue_Cases"], bins=30, kde=True, color="blue")
plt.xlabel("Dengue Cases")
plt.ylabel("Frequency")
plt.title("Distribution of Dengue Cases")
plt.show()

# %% [markdown]
# <h1 style='color:blue'>Insight 13</h1>
# <h3>The linegraph shows that dengue cases peak in August and September, with the highest number of infections recorded during these months. Dengue deaths remain relatively low throughout the year but increase slightly around the peak infection months, indicating a higher risk during outbreaks.</h3>

# %%
monthly_totals = dengue.groupby("Month")[["Dengue_Cases", "Dengue_Deaths"]].sum().reindex(month_order)

plt.figure(figsize=(12, 5))
sns.lineplot(data=monthly_totals, marker="o")
plt.xlabel("Month")
plt.ylabel("Total Cases and Deaths")
plt.title("Total Dengue Cases and Deaths per Month")
plt.legend(["Dengue Cases", "Dengue Deaths"])
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# <h1 style='color:blue'>Insight 14</h1>
# <h3>The histogram shows that most dengue death rates are very low, but a few extreme cases have much higher death rates. The distribution is highly skewed, indicating that while dengue is usually not fatal, certain outbreaks can be much more severe.</h3>

# %%
percentages = dengue["Death_Rate"] = (dengue["Dengue_Deaths"] / dengue["Dengue_Cases"]) * 100
print(percentages)

plt.figure(figsize=(10, 5))
sns.histplot(dengue["Death_Rate"].dropna(), bins=20, kde=True, color="purple")
plt.xlabel("Death Rate (%)")
plt.ylabel("Frequency")
plt.title("Distribution of Death Rates")
plt.show()
# Out:
# 0        0.141844
# 1        0.000000
# 2        0.000000
# 3        0.833333
# 4        0.411523
#           ...
# 1015     0.000000
# 1016    50.000000
# 1017    69.230769
# 1018     6.666667
# 1019     0.000000
# Length: 1020, dtype: float64

# %% [markdown]
# <h1 style='color:blue'>Insight 15</h1>
# <h3>The bar chart shows that the average number of dengue cases was significantly higher in the 2010s compared to the 2020s. This decrease may be due to improved healthcare, preventive measures, or other external factors affecting dengue transmission.</h3>

# %%
dengue["Decade"] = (dengue["Year"] // 10) * 10
decade_cases = dengue.groupby("Decade")["Dengue_Cases"].mean()

plt.figure(figsize=(8, 5))
sns.barplot(x=decade_cases.index.astype(str), y=decade_cases.values, palette="coolwarm")
plt.xlabel("Decade")
plt.ylabel("Average Dengue Cases")
plt.title("Average Dengue Cases per Decade")
plt.show()

# %% [markdown]
# <h1 style='color:blue'>Insight 16</h1>
# <h3>The barplot shows that dengue cases were the highest in 2019, much more than in other years. This means there was a major outbreak, highlighting the need for better prevention and control efforts.</h3>

# %%
yearly_cases = dengue.groupby("Year")["Dengue_Cases"].sum().nlargest(5)

plt.figure(figsize=(10, 5))
sns.barplot(x=yearly_cases.index.astype(str), y=yearly_cases.values, palette="magma")
plt.xlabel("Year")
plt.ylabel("Total Dengue Cases")
plt.title("Top 5 Worst Years for Dengue Cases")
plt.show()

# %% [markdown]
# <h1 style='color:blue'>Insight 17</h1>
# <h3>The chart shows that 2016 had the highest number of dengue-related deaths, much more than other years. This suggests a particularly deadly outbreak that year, highlighting the importance of better healthcare and prevention measures.</h3>

# %%
yearly_deaths = dengue.groupby("Year")["Dengue_Deaths"].sum().nlargest(5)

plt.figure(figsize=(10, 5))
sns.barplot(x=yearly_deaths.index.astype(str), y=yearly_deaths.values, palette="coolwarm")
plt.xlabel("Year")
plt.ylabel("Total Dengue Deaths")
plt.title("Top 5 Worst Years for Dengue Deaths")
plt.show()

# %% [markdown]
# <h1 style='color:blue'>Insight 18</h1>
# <h3>The barplot shows that dengue cases are highest in autumn and summer, while they are lowest in spring. This suggests that warmer and more humid conditions during these seasons may create a favorable environment for mosquito breeding, increasing the risk of dengue transmission.</h3>

# %%
season_mapping = {
    "December": "Winter", "January": "Winter", "February": "Winter",
    "March": "Spring", "April": "Spring", "May": "Spring",
    "June": "Summer", "July": "Summer", "August": "Summer",
    "September": "Autumn", "October": "Autumn", "November": "Autumn"
}
dengue["Season"] = dengue["Month"].map(season_mapping)
seasonal_cases = dengue.groupby("Season")["Dengue_Cases"].mean()

plt.figure(figsize=(8, 5))
sns.barplot(x=seasonal_cases.index, y=seasonal_cases.values, palette="coolwarm")
plt.xlabel("Season")
plt.ylabel("Average Dengue Cases")
plt.title("Seasonal Trend of Dengue Cases")
plt.show()

# %% [markdown]
# <h1 style='color:blue'>Insight 19</h1>
# <h3>The lineplot shows that dengue cases peaked sharply in 2019 before dropping significantly in 2020, while dengue deaths remained relatively low throughout the years. This suggests that although 2019 saw a major outbreak, the fatality rate may have been controlled due to improved healthcare or timely interventions.</h3>

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=dengue.groupby("Year")[["Dengue_Cases", "Dengue_Deaths"]].sum(), marker="o")
plt.xlabel("Year")
plt.ylabel("Total Cases and Deaths")
plt.title("Comparison of Dengue Cases and Deaths Over the Years")
plt.legend(["Dengue Cases", "Dengue Deaths"])
plt.grid()
plt.show()

# %% [markdown]
# <h1 style='color:blue'>Insight 20</h1>
# <h3>The lineplot shows that dengue cases peak in August and September, while they are lowest in April and May. This trend suggests that dengue outbreaks are more common during late summer and early autumn, possibly due to favorable weather conditions for mosquito breeding and transmission.</h3>

# %%
monthly_cases = dengue.groupby("Month")["Dengue_Cases"].sum()

plt.figure(figsize=(10, 6))
sns.lineplot(x=monthly_cases.index, y=monthly_cases.values, marker='o', color='blue')
plt.xlabel("Month")
plt.ylabel("Total Dengue Cases")
plt.title("Monthly Dengue Cases Trend")
plt.show()

print("Monthly Dengue Cases:")
print(monthly_cases)
# Out:
# Monthly Dengue Cases:
# Month
# April         32508
# August       187554
# December      88431
# February      77801
# January       84328
# July         138242
# June          58110
# March         57576
# May           32387
# November      94900
# October      117645
# September    177943
# Name: Dengue_Cases, dtype: int64

# %% [markdown]
# <h1 style='color:blue'>Insight 21</h1>
# <h3>The barplot shows that dengue mortality rates were highest in 2016 and 2017 but dropped significantly in 2018 and 2019. However, there was a slight increase in 2020, suggesting that while treatment and prevention improved, challenges in controlling severe cases still existed.</h3>

# %%
dengue_mortality = (dengue.groupby("Year")["Dengue_Deaths"].sum() / dengue.groupby("Year")["Dengue_Cases"].sum()) * 100
plt.figure(figsize=(10, 6))
sns.barplot(x=dengue_mortality.index, y=dengue_mortality.values, palette="Reds")
plt.xlabel("Year")
plt.ylabel("Mortality Rate (%)")
plt.title("Dengue Mortality Rate Per Year")
plt.show()
print("Dengue Mortality Rate Per Year:")
print(dengue_mortality)
# Out:
# Dengue Mortality Rate Per Year:
# Year
# 2016    3.878422
# 2017    2.960008
# 2018    0.488869
# 2019    0.392168
# 2020    1.312595
# dtype: float64
